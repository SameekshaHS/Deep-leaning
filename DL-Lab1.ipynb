# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
print("Array:", arr)
print("Sum:", np.sum(arr))
print("Mean:", np.mean(arr))
print("Max:", np.max(arr))
print("Min:", np.min(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# Array: [10 20 30 40 50]
# Sum: 150
# Mean: 30.0
# Max: 50
# Min: 10
# Standard Deviation: 14.142135623730951

# %%
import pandas as pd
data = {
    "Name": ["Asha", "Ravi", "Kiran", "Meena", "Arjun"],
    "Age": [20, 21, 19, 20, 22],
    "Gender": ["F", "M", "M", "F", "M"],
    "Math": [85, 78, 92, 88, 76],
    "Science": [90, 82, 88, 91, 79],
    "English": [75, 80, 85, 87, 70]
}
df = pd.DataFrame(data)
print("Dataset:")
print(df)
print("\nInfo:")
print(df.info())
print("\nSummary:")
print(df.describe())
df["Average"] = df[["Math", "Science", "English"]].mean(axis=1)
print("\nDataset with Average:")
print(df)
# Out:
# Dataset:
#     Name  Age Gender  Math  Science  English
# 0   Asha   20      F    85       90       75
# 1   Ravi   21      M    78       82       80
# 2  Kiran   19      M    92       88       85
# 3  Meena   20      F    88       91       87
# 4  Arjun   22      M    76       79       70
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Age      5 non-null      int64
#  2   Gender   5 non-null      object
#  3   Math     5 non-null      int64
#  4   Science  5 non-null      int64
#  5   English  5 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 368.0+ bytes
# None
#
# Summary:
#              Age       Math    Science    English
# count   5.000000   5.000000   5.000000   5.000000
# mean   20.400000  83.800000  86.000000  79.400000
# std     1.140175   6.723095   5.244044   7.021396
# min    19.000000  76.000000  79.000000  70.000000
# 25%    20.000000  78.000000  82.000000  75.000000
# 50%    20.000000  85.000000  88.000000  80.000000
# 75%    21.000000  88.000000  90.000000  85.000000
# max    22.000000  92.000000  91.000000  87.000000
#
# Dataset with Average:
#     Name  Age Gender  Math  Science  English    Average
# 0   Asha   20      F    85       90       75  83.333333
# 1   Ravi   21      M    78       82       80  80.000000
# 2  Kiran   19      M    92       88       85  88.333333
# 3  Meena   20      F    88       91       87  88.666667
# 4  Arjun   22      M    76       79       70  75.000000
